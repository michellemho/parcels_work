# %% [markdown]
# # Map basemap of wind curl (no trajectories)

# %%
# !pip install netCDF4
# Out:
# Collecting netCDF4
#   Downloading https://files.pythonhosted.org/packages/f9/7c/5dfcf562d092df919b0b999adeed7769005497a6cd397adff5103b9a81e5/netCDF4-1.4.1-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (4.9MB)
#     100% |████████████████████████████████| 4.9MB 350kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.7 in /anaconda3/lib/python3.6/site-packages (from netCDF4)
# Collecting cftime (from netCDF4)
#   Downloading https://files.pythonhosted.org/packages/bf/f6/3045262ece2e730183b1f82d2ac7190ed12422c1ef43c8059bae210220ca/cftime-1.0.1.tar.gz
# Building wheels for collected packages: cftime
#   Running setup.py bdist_wheel for cftime ... done
#   Stored in directory: /Users/mho/Library/Caches/pip/wheels/68/ed/ad/f3c802b1612914988c33e9f2fc422c0acfdc23669864e833ba
# Successfully built cftime
# Installing collected packages: cftime, netCDF4
# Successfully installed cftime-1.0.1 netCDF4-1.4.1
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
# %matplotlib inline
# Out:
# -------------------------------------------------------
# ModuleNotFoundError   Traceback (most recent call last)
# <ipython-input-1-0cd9fe7641b5> in <module>()
#       1 import numpy as np
# ----> 2 from netCDF4 import Dataset
#       3 import matplotlib.pyplot as plt
#       4 from mpl_toolkits.basemap import Basemap
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'netCDF4'

# %%
wind_data = Dataset('ASCAT_wind_and_curl_5yearmean.cdf')

# %%
# Set up mapper with a Basemap of coastal boundaries for Hawaii

mapper = Basemap(projection='merc',
            llcrnrlon=194.125,
            llcrnrlat=16.125,
            urcrnrlon=208.875,
            urcrnrlat=25.875,
            resolution='l')

# Set up processing for bathymetry data
lats = wind_data.variables['LAT385_424'][:]
lons = wind_data.variables['LON1497_1556'][:]
WINDCURL_OUT = wind_data.variables['CURLM'][:] 

lons,lats= np.meshgrid(lons,lats)
x,y = mapper(lons,lats)

# Create contour object and add to the mapper
curl = mapper.contourf(x,y,WINDCURL_OUT[0])

# Add legend
cb = mapper.colorbar(curl,orientation='vertical', size="5%", pad="2%")
cb.set_label('Wind stress curl [x10^(-6) Pa m^(-1)]')

plt.savefig('Fig2b_SI.png', format='png', dpi=1000)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MaskError                                 Traceback (most recent call last)
# <ipython-input-19-6dae9bc54e4a> in <module>()
#      17
#      18 # Create contour object and add to the mapper
# ---> 19 curl = mapper.contourf(x,y,WINDCURL_OUT[0])
#      20
#      21 # Add legend
#
# /Users/davidlindo-atichati/miniconda2/envs/maps_chad/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in with_transform(self, x, y, data, *args, **kwargs)
#     534             # convert lat/lon coords to map projection coords.
#     535             x, y = self(x,y)
# --> 536         return plotfunc(self,x,y,data,*args,**kwargs)
#     537     return with_transform
#     538
#
# /Users/davidlindo-atichati/miniconda2/envs/maps_chad/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in contourf(self, x, y, data, *args, **kwargs)
#    3659                 # combine with data mask.
#    3660                 mask = np.logical_or(ma.getmaskarray(data),xymask)
# -> 3661                 data = ma.masked_array(data,mask=mask)
#    3662                 CS = ax.contourf(x,y,data,*args,**kwargs)
#    3663         finally:
#
# /Users/davidlindo-atichati/miniconda2/envs/maps_chad/lib/python2.7/site-packages/numpy/ma/core.pyc in __new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order, **options)
#    2866                     msg = "Mask and data not compatible: data size is %i, " + \
#    2867                           "mask size is %i."
# -> 2868                     raise MaskError(msg % (nd, nm))
#    2869                 copy = True
#    2870             # Set the mask to the new value
#
# MaskError: Mask and data not compatible: data size is 60, mask size is 2400.

# %%
WINDCURL_OUT
# Out:
# masked_array(
#   data=[[-0.058568810031208014, -0.06267010731940349,
#          -0.07786670560574911, ..., -0.007493950822120132,
#          -0.0073853480466341955, -0.0038668660079402136],
#         [-0.07034416650359414, -0.07029736639852079,
#          -0.07804835707817297, ..., -0.009877776389308616,
#          -0.017190818081725553, -0.02011143162547541],
#         [-0.06171427244533341, -0.05505159161289716,
#          -0.06574265129051643, ..., -0.006688913362402898,
#          -0.01776737808826342, -0.03602105997665939],
#         ...,
#         [-0.05147492114285319, -0.04586893951241203,
#          -0.05065352741144947, ..., -0.07492409208826567,
#          -0.05284443204760631, -0.05284843177846202],
#         [-0.06632387706234813, -0.06621336964584552,
#          -0.05679187115489539, ..., -0.06863255788374704,
#          -0.061649924783032814, -0.05364390475286851],
#         [-0.08092920863685531, -0.07898146483403488,
#          -0.06587201998854662, ..., -0.07606994243115123,
#          -0.06923382465841457, -0.0645146524247106]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-1e+34)

# %%
x
# Out:
# array([[      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905],
#        [      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905],
#        [      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905],
#        ...,
#        [      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905],
#        [      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905],
#        [      0.        ,   27798.71857117,   55597.43714234, ...,
#         1584526.95855671, 1612325.67712788, 1640124.39569905]])
